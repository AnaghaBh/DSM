# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = r"C:\Users\DELL\Downloads\final_cleaned_user_data.csv" 
df = pd.read_csv(file_path)

print("Head of the dataset:")
display(df.head())

print("Info:")
df.info()

print("\nSummary statistics:")
display(df.describe())

if 'review_count' in df.columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df['review_count'], bins=50, kde=True)
    plt.title('Distribution of Review Count')
    plt.xlabel('Review Count')
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Head of the dataset:
#                   user_id  review_count        yelping_since     useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w      6.801819  2007-01-25 16:47:26  11.184602
# 1  j14WgRoU_-2ZE1aw1dXrJg     52.195273  2009-01-25 04:35:42  67.108366
# 2  2WnXYQFK0hXEoTxPtV2zvg      7.770729  2008-07-25 10:41:00   3.185917
# 3  SZDeASXq7o05mMNLshsdIA      2.429611  2005-11-29 04:38:33   0.732218
# 4  hA5lMy-EnncsH4JoR-hFGQ      0.673460  2007-01-05 19:40:59  -0.020728
#
#        funny       cool                                              elite  \
# 0   3.045658  10.560175                                               2007
# 1  31.998339  48.212880  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   2.435070   1.732033                           2009,2010,2011,2012,2013
# 3   0.767599   0.486790                                     2009,2010,2011
# 4  -0.004832  -0.029704                                                NaN
#
# ...

# %%
df = df.dropna(subset=['user_id'])

df['elite'] = df['elite'].fillna('')
df['friends'] = df['friends'].fillna('')

df = df[df['review_count'] > 0]

print(f"Remaining users after filtering: {len(df)}")
df.head()
# Out:
# Remaining users after filtering: 374650
#                   user_id  review_count        yelping_since     useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w      6.801819  2007-01-25 16:47:26  11.184602
# 1  j14WgRoU_-2ZE1aw1dXrJg     52.195273  2009-01-25 04:35:42  67.108366
# 2  2WnXYQFK0hXEoTxPtV2zvg      7.770729  2008-07-25 10:41:00   3.185917
# 3  SZDeASXq7o05mMNLshsdIA      2.429611  2005-11-29 04:38:33   0.732218
# 4  hA5lMy-EnncsH4JoR-hFGQ      0.673460  2007-01-05 19:40:59  -0.020728
#
#        funny       cool                                              elite  \
# 0   3.045658  10.560175                                               2007
# 1  31.998339  48.212880  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   2.435070   1.732033                           2009,2010,2011,2012,2013
# 3   0.767599   0.486790                                     2009,2010,2011
# 4  -0.004832  -0.029704
#
#                                              friends        fans  \
# ...

# %%
df = df[~((df['review_count'] < 5) & (df['friend_count'] == 0))]
df.head()
print(len(df))
df.to_csv(r"C:\Users\DELL\Downloads\prematched_user_data.csv", index=False)
# Out:
# 318325

# %%
df_review_food = pd.read_csv(r"C:\Users\DELL\Downloads\cleaned_review_food.csv")
df_user = pd.read_csv(r"C:\Users\DELL\Downloads\prematched_user_data.csv") 

relevant_user_ids = set(df_review_food['user_id'])

df_user_filtered = df_user[df_user['user_id'].isin(relevant_user_ids)]

print(f"Remaining users: {len(df_user_filtered)}")
df_user_filtered.head()
# Out:
# Remaining users: 19405
#                     user_id  review_count        yelping_since     useful  \
# 1    j14WgRoU_-2ZE1aw1dXrJg     52.195273  2009-01-25 04:35:42  67.108366
# 27   NIhcRW6DWvk1JQhDhXwgOQ     27.427500  2005-12-30 13:47:19  19.845818
# 43   IpLRJY4CP3fXtlEd8Y4GFQ      5.990357  2009-04-11 14:35:46   1.999599
# 53   LwZJFLGxQwjjeOgpqTJnfw      1.618148  2010-09-21 18:14:11   0.077483
# 104  0G-QF457q_0Z_jKqh6xWiA     24.048425  2008-03-12 19:13:45  42.237771
#
#          funny       cool                                              elite  \
# 1    31.998339  48.212880  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 27   10.255015  14.057117  2006,2007,2008,2009,2010,2011,2012,2013,2014,2...
# 43    1.061859   0.573461                                     2009,2010,2011
# 53    0.051568   0.023361                                                NaN
# 104  34.408815  36.015151  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
#
# ...

# %% [markdown]
# #common users found from matching this user dataset with the reviews user_id filtered set which was filtered using only the users who reviewed the business ids as in the business data set: Remaining users: 19405

# %%
df_user_filtered = df_user_filtered.copy()
df_user_filtered['yelping_since'] = pd.to_datetime(df_user_filtered['yelping_since'], errors='coerce')
df_user_filtered = df_user_filtered[df_user_filtered['yelping_since'].dt.year >= 2018]
df_user_filtered.head()
print(len(df_user_filtered))
# Out:
# 1988

# %%
df_user_filtered.to_csv(r"C:\Users\DELL\Downloads\filtered_user_data.csv", index=False)

# %%
file_path = r"C:\Users\DELL\Downloads\filtered_user_data.csv" 
df = pd.read_csv(file_path)

print("Head of the dataset:")
display(df.head())
# Out:
# Head of the dataset:
#                   user_id  review_count        yelping_since    useful  \
# 0  DtVbjJ0YL1RSCTy1l4IqpA      0.685572  2018-05-31 20:24:52  0.021363
# 1  huYvzsRyRfyjwZn1LFWIQw      0.479678  2018-09-16 23:35:15  0.036952
# 2  9EAVqhTCw5_L7I6xwj5VbA      1.363809  2018-12-18 18:12:13  0.057217
# 3  _DzaaJMI7mCVGtDLRCKfsA      0.019446  2018-10-23 16:18:13 -0.051905
# 4  ILAP9a1OZJBEJcT_0REVkw      1.206361  2018-10-12 01:25:27  0.418881
#
#       funny      cool            elite  \
# 0 -0.021997  0.002135        2018,2019
# 1 -0.007284  0.010979       2019,20,20
# 2 -0.017093  0.032205  2019,20,20,2021
# 3 -0.041615 -0.042085              NaN
# 4 -0.009736  0.403655  2019,20,20,2021
#
#                                              friends      fans  average_stars  \
# 0  Qzvj-gqiFVdtHdhy3wlu9w, vUs_WVXpIutmnosD-JT2Zw...  0.194932       0.134793
# 1  4kBZ1os1fxQeAQTlTxMFjA, B2Kgi4sOmoQiegdcQAAtmQ...  0.029467       0.726341
# ...

# %%
print(df['friends'].head(1))
# Out:
# 0    Qzvj-gqiFVdtHdhy3wlu9w, vUs_WVXpIutmnosD-JT2Zw...
# Name: friends, dtype: object
